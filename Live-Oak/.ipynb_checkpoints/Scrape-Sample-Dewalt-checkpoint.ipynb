# %%
import pandas as pd
import glob
import re

# ONLY LINE THAT NEEDS CHANGING - UPDATE THE FILE NAME. THE FILE_NAME GETS USED IN LAST CODE BLOCK, TOO.
#file_name = "Henkel-Corporation-ManufacturerExport-2-1-2021"

files_list = glob.glob("*ManufacturerExport*.csv")
for file in files_list:
    df = pd.read_csv(file)
    
    # Delete Unnecessary Columns.
    needed_columns = ['category_ids', 'category_names', 'sku', 'meta_title', 'meta_description', 'Image', 
                      'manufacturer', 'description', 'short_description', 'summary', 'upc', 'size_info', 'meta_keyword']
    df = df[df.columns.intersection(needed_columns)]

#     # Replace all NaNs with nothing, without deleting the text "nan" from things like "NANo filter" or "MainteNANce"
#     df = df.fillna('')
#     df = file_no_html.astype(str)
#     for col in df.columns:
#         file_no_html[col] = file_no_html[col].replace({'<[^<]+?>' : '', '\(bul\)' : '', '&quot;' : '"', '&trade;' : '™'}, regex=True)

    # Replace first "/\" in Image column with "E:\IMAGES\ITEMS\product\"
    df['Image'] = df['Image'].str.replace('/\\\\', 'E:\\\\IMAGES\\\\ITEMS\\\\product\\\\')
    df = df.replace({'\\r\\n':' ', '\\r':' ', '\\n':' ', '&176;':'°', '&nbsp;':' ', 'nbsp;':' ',
                     '&#176;':'°', '&#153;':'™', '&reg;':'®', '&#174;':'®', '&trade;':'™', '<[^<]+?>' : '',
                     '\(bul\)' : '', '&quot;' : '"'}
                    , regex=True)
    df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

    print(df.head)
    # Make sure the file named below is closed in Excel or else code won't run:
    #Change the folder path accordingly and make sure folder exists. This is where the file will save.
    folder_path = "../Samples/" + file
    df.to_csv(folder_path, encoding='utf-8-sig', index=False)
# Out:
# <ipython-input-3-a3309b452816>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Image'] = df['Image'].str.replace('/\\\\', 'E:\\\\IMAGES\\\\ITEMS\\\\product\\\\')
# <bound method NDFrame.head of         category_ids                                     category_names  \
# 0     81|24729|28340  Staplers|Air Staplers|Nailers and Staplers (Am...
# 1     81|24729|28340  Staplers|Air Staplers|Nailers and Staplers (Am...
# 2              24729                                       Air Staplers
# 3          137|24669         Air Compressors|Air Line System Components
# 4              24590                                Gas Air Compressors
# ...              ...                                                ...
# 2907           20356                                    Drop-In Anchors
# 2908           20356                                    Drop-In Anchors
# 2909           27844                                    Hex Head Screws
# 2910           27844                                    Hex Head Screws
# 2911           27679                               Impact Hammer Drills
#
#              sku                                         meta_title  \
# 0        D51420K          1'' x 1/4'' 18 Gauge Narrow Crown Stapler
# 1         D51430   1'' - 2'' x 7/16'' 16 Gauge Medium Crown Stapler
# 2        D51422K      1-1/2'' x 1/4'' 18 Gauge Narrow Crown Stapler
# 3         D55040        Quadraport Air Line Splitter with Regulator
# 4         D55146  1.6 HP Continuous, 200 PSI, 4.5 Gallon Compressor
# ...          ...                                                ...
# 2907  PFM2101720            DEWALT PFM2101720 3/8 SDS+ SETTING TOOL
# 2908  PFM2111820  DEWALT PFM2111820 3/8X3/4 MINI-UNDERCUT+ ANCHO...
# 2909  PFM2231100  DEWALT PFM2231100 HANGERMATE+ 3/8 ROD 1/4X1^ V...
# 2910  PFM2251100  DEWALT PFM2251100 HANGERMATE+ 3/8 ROD 1/4X2 VE...
# 2911  PPA2431720  DEWALT PPA2431720 5/8X3/4 SDS+ HAMMER DRILL ST...
#
#                                        meta_description  \
# 0     Tool-free thumb wheel depth setting for quick ...
# 1     Lightweight tool provides enhanced maneuverabi...
# 2     Tool-free indexed depth setting is lockable an...
# 3     Factory tested to assure leak-free operation. ...
# 4     200 PSI max tank storage pressure provides a u...
# ...                                                 ...
# 2907                                                NaN
# 2908                                                NaN
# 2909                                                NaN
# 2910                                                NaN
# 2911                                                NaN
#
#                                                   Image manufacturer  \
# 0     E:\IMAGES\ITEMS\product\D\5\DeWalt-D51420K-1-x...       DeWalt
# 1     E:\IMAGES\ITEMS\product\D\5\DeWalt-D51430-1-2-...       DeWalt
# 2     E:\IMAGES\ITEMS\product\D\5\DeWalt-D51422K-1-1...       DeWalt
# 3     E:\IMAGES\ITEMS\product\D\5\DeWalt-D55040-Quad...       DeWalt
# 4     E:\IMAGES\ITEMS\product\D\5\DeWalt-D55146-18-H...       DeWalt
# ...                                                 ...          ...
# 2907  E:\IMAGES\ITEMS\product\P\F\dewalt-pfm2101720-...       DeWalt
# 2908  E:\IMAGES\ITEMS\product\P\F\dewalt-pfm2111820-...       DeWalt
# 2909  E:\IMAGES\ITEMS\product\P\F\dewalt-pfm2231100-...       DeWalt
# 2910  E:\IMAGES\ITEMS\product\P\F\dewalt-pfm2251100-...       DeWalt
# 2911  E:\IMAGES\ITEMS\product\P\P\dewalt-ppa2431720-...       DeWalt
#
#                                             description  \
# 0     DeWalt D51420K 1'' x 1/4'' 18 Gauge Narrow Cro...
# 1     DeWalt  D51430 1'' - 2'' x 7/16'' 16 Gauge Med...
# 2     DeWalt  D51422K 1-1/2'' x 1/4'' 18 Gauge Narro...
# 3     DeWalt  D55040 Quadraport Air Line Splitter wi...
# 4     DeWalt  D55146 1.8 HP Continuous, 200 PSI, 4.5...
# ...                                                 ...
# 2907                                                NaN
# 2908                                                NaN
# 2909                                                NaN
# 2910                                                NaN
# 2911                                                NaN
#
#                                       short_description  \
# 0     Fastener Style 18 gauge stapleCrown Size 1/4''...
# 1     Fastener Style 16 gauge stapleCrown Size 7/16'...
# 2     Fastener Style 18 gauge stapleCrown Size 1/4''...
# 3     HP n/aHPDrive n/aTank Size n/agalPower Supply ...
# 4     Drive Belt DriveHP 1.8HPTank Size 4.5galPower ...
# ...                                                 ...
# 2907  Item: Drop-in Anchor Setting Tool  Constructio...
# 2908  Item: Drop-In Anchor  Drop-In Anchor Type: Non...
# 2909  Requires no pre-drilling Zinc-plated for corro...
# 2910  Requires no pre-drilling Zinc-plated for corro...
# 2911  Drill Bit Grouping: Drill Bit  Item: Hammer Dr...
#
#                                                 summary           upc  \
# 0     Tool-free thumb wheel depth setting for quick ...           NaN
# 1     Lightweight tool provides enhanced maneuverabi...           NaN
# 2     Tool-free indexed depth setting is lockable an...           NaN
# 3     Factory tested to assure leak-free operation. ...           NaN
# 4     Features &amp; Specs                          ...           NaN
# ...                                                 ...           ...
# 2907                                                NaN  7.535231e+09
# 2908                                                NaN  7.535231e+09
# 2909  DeWalt® Engineered Vertical Threaded Rod Hange...           NaN
# 2910  DeWalt® Engineered Vertical Threaded Rod Hange...           NaN
# 2911                                                NaN  7.535231e+09
#
#                                               size_info  \
# 0     DeWalt D51420K 1'' x 1/4'' 18 Gauge Narrow Cro...
# 1     DeWalt  D51430 1'' - 2'' x 7/16'' 16 Gauge Med...
# 2     DeWalt  D51422K 1-1/2'' x 1/4'' 18 Gauge Narro...
# 3     DeWalt  D55040 Quadraport Air Line Splitter wi...
# 4     DeWalt  D55146 1.8 HP Continuous, 200 PSI, 4.5...
# ...                                                 ...
# 2907                                                NaN
# 2908                                                NaN
# 2909                                                NaN
# 2910                                                NaN
# 2911                                                NaN
#
#                                            meta_keyword
# 0             1'' x 1/4'' 18 Gauge Narrow Crown Stapler
# 1      1'' - 2'' x 7/16'' 16 Gauge Medium Crown Stapler
# 2         1-1/2'' x 1/4'' 18 Gauge Narrow Crown Stapler
# 3           Quadraport Air Line Splitter with Regulator
# 4     1.6 HP Continuous, 200 PSI, 4.5 Gallon Compressor
# ...                                                 ...
# 2907            DEWALT PFM2101720 3/8 SDS+ SETTING TOOL
# 2908  DEWALT PFM2111820 3/8X3/4 MINI-UNDERCUT+ ANCHO...
# 2909  DEWALT PFM2231100 HANGERMATE+ 3/8 ROD 1/4X1^ V...
# 2910  DEWALT PFM2251100 HANGERMATE+ 3/8 ROD 1/4X2 VE...
# 2911  DEWALT PPA2431720 5/8X3/4 SDS+ HAMMER DRILL ST...
#
# [2912 rows x 13 columns]>
# ---------------------------------------------------------------------------
# OSError                                   Traceback (most recent call last)
# <ipython-input-3-a3309b452816> in <module>
#      33     #Change the folder path accordingly and make sure folder exists. This is where the file will save.
#      34     folder_path = "../Samples/"
# ---> 35     df.to_csv(folder_path, encoding='utf-8-sig', index=False)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# OSError: [Errno 22] Invalid argument: '../Samples/'
