# %%
import pandas as pd
import glob
import re

# ONLY LINE THAT NEEDS CHANGING - UPDATE THE FILE NAME. THE FILE_NAME GETS USED IN LAST CODE BLOCK, TOO.
#file_name = "Henkel-Corporation-ManufacturerExport-2-1-2021"

files_list = glob.glob("*ManufacturerExport*.csv")
for file in files_list:
    df = pd.read_csv(file)
    
    # Delete Unnecessary Columns.
    needed_columns = ['category_ids', 'category_names', 'sku', 'meta_title', 'meta_description', 'Image', 
                      'manufacturer', 'description', 'short_description', 'summary', 'upc', 'size_info', 'meta_keyword']
    df = df[df.columns.intersection(needed_columns)]

#     # Replace all NaNs with nothing, without deleting the text "nan" from things like "NANo filter" or "MainteNANce"
#     df = df.fillna('')
#     df = file_no_html.astype(str)
#     for col in df.columns:
#         file_no_html[col] = file_no_html[col].replace({'<[^<]+?>' : '', '\(bul\)' : '', '&quot;' : '"', '&trade;' : '™'}, regex=True)

    # Replace first "/\" in Image column with "E:\IMAGES\ITEMS\product\"
    df['Image'] = df['Image'].str.replace('/\\\\', 'E:\\\\IMAGES\\\\ITEMS\\\\product\\\\')
    df = df.replace({'\\r\\n':' ', '\\r':' ', '\\n':' ', '&176;':'°', '&nbsp;':' ', 'nbsp;':' ',
                     '&#176;':'°', '&#153;':'™', '&#174;':'®', '&trade;':'™', '<[^<]+?>' : '',
                     '\(bul\)' : '', '&quot;' : '"'}
                    , regex=True)
    df = df.apply(lambda x: x.str.strip() if x.dtype == "object" else x)

    print(df.head)
    # Make sure the file named below is closed in Excel or else code won't run:
    #Change the folder path accordingly and make sure folder exists. This is where the file will save.
    folder_path = "./Properly-Formatted-Files/" + 'v2' + file
    df.to_csv(folder_path, encoding='utf-8-sig', index=False)
# Out:
# <bound method NDFrame.head of     category_ids                                     category_names  \
# 0      223|25662                        Manual Rope Grab|Rope Grabs
# 1      216|25656                    Non Stretch Harnesses|Harnesses
# 2      221|25664  Shock Absorbing - Lanyards|Shock-Absorbing Lan...
# 3      216|25656                    Non Stretch Harnesses|Harnesses
# 4      221|25664  Shock Absorbing - Lanyards|Shock-Absorbing Lan...
# ..           ...                                                ...
# 341        19603                                    Packaging Tapes
# 342        19603                                    Packaging Tapes
# 343        19603                                    Packaging Tapes
# 344   1326|19703        Cleaning Supplies|Cleaning Supplies Holders
# 345        25952                             Cartridges and Filters
#
#                 sku                                         meta_title  \
# 0              0113  Steel Dual Cam Rope Grab, Fall Protection 5/8"...
# 1            1050-R            Feather Harness Fall Protection Harness
# 2              3560  6' Dual Leg Lanyard w/ Shock Absorber 100% Tie...
# 3    1051-N460-LOGO  Feather Positioning Harness with Back and Wais...
# 4              3561  6' Shock Absorbing Lanyard with Clip to Tie Ba...
# ..              ...                                                ...
# 341     70500010189                            Vinyl Tape 471 - Yellow
# 342     70002413030                            Vinyl Tape 471 - Yellow
# 343     70500010023                            Vinyl Tape 471 - Yellow
# 344     70070653897                              10/pack, 6 packs/case
# 345            8210                    8210 Performance Respirator N95
#
#                                       meta_description  \
# 0    3M 0113 Steel Dual Cam Rope Grab, Fall Protect...
# 1    3M 1050-R Feather Harness Fall Protection Harness
# 2    3M™ Dual Leg Lanyard, 100% Tie-Off 6`with Shoc...
# 3     3M™ Fall Protection Harness 1051-N460-LOGO, 1/cs
# 4    3M™ Shock Absorbing Lanyard, 6` with Clip to T...
# ..                                                 ...
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
# 344  Dual-action cleaning tool. Highly conformable ...
# 345                                                NaN
#
#                                                  Image manufacturer  \
# 0    E:\IMAGES\ITEMS\product\0\1\3M-0113-Steel-Dual...           3M
# 1    E:\IMAGES\ITEMS\product\1\0\3M-1050-R-Feather-...           3M
# 2    E:\IMAGES\ITEMS\product\3\5\3M-3560-6-Dual-Leg...           3M
# 3    E:\IMAGES\ITEMS\product\1\0\3M-1051-N460-LOGO-...           3M
# 4    E:\IMAGES\ITEMS\product\3\5\3M-3561-6-Shock-Ab...           3M
# ..                                                 ...          ...
# 341  E:\IMAGES\ITEMS\product\7\0\3m-70500010189-vin...           3M
# 342  E:\IMAGES\ITEMS\product\7\0\3m-70002413030-vin...           3M
# 343  E:\IMAGES\ITEMS\product\7\0\3m-70500010023-vin...           3M
# 344  E:\IMAGES\ITEMS\product\6\1\Scotch-Brite-Mediu...           3M
# 345  E:\IMAGES\ITEMS\product\8\2\8210-Performance-R...           3M
#
#                                            description  \
# 0    3M 0113 Steel Dual Cam Rope Grab, Fall Protect...
# 1    3M 1050-R Feather Harness Fall Protection Harness
# 2    3M™ Dual Leg Lanyard, 100% Tie-Off 6`with Shoc...
# 3                          3M™ Fall Protection Harness
# 4    3M™ Shock Absorbing Lanyard, 6` with Clip to T...
# ..                                                 ...
# 341                                                NaN
# 342                                                NaN
# 343                                                NaN
# 344                              10/pack, 6 packs/case
# 345                                                NaN
#
#                                      short_description  \
# 0      Steel Dual Cam Rope Grab, 5/8" & 3/4" 1 ea/case
# 1    Fall Protection Harness 1050-R with rescue str...
# 2    6' 100% Tie-Off Shock Absorbing Dual Leg Lanya...
# 3       3M™ Fall Protection Harness Back waist d-rings
# 4    6' Shock Absorbing Lanyard with Clip to Tie Ba...
# ..                                                 ...
# 341  3M Vinyl Tape 471 is a comformable colored tap...
# 342  3M Vinyl Tape 471 is a comformable colored tap...
# 343  3M Vinyl Tape 471 is a comformable colored tap...
# 344  Highly comformable web laminate to a sponge ba...
# 345  Use for non-harmful dusts related to: Sanding,...
#
#                                                summary           upc  \
# 0                                                  NaN           NaN
# 1                                                  NaN           NaN
# 2                                                  NaN           NaN
# 3                                                  NaN           NaN
# 4                                                  NaN           NaN
# ..                                                 ...           ...
# 341                                                NaN           NaN
# 342                                                NaN           NaN
# 343                                                NaN           NaN
# 344  ApplicationsCommercial Kitchen CleaningBrandSc...  5.004801e+13
# 345                                                NaN           NaN
#
#                                              size_info  \
# 0    3M 0113 Steel Dual Cam Rope Grab, Fall Protect...
# 1    3M 1050-R Feather Harness Fall Protection Harness
# 2    3M 3560 6' Dual Leg Lanyard w/ Shock Absorber ...
# 3                                            N460-LOGO
# 4    3M 3561 6' Shock Absorbing Lanyard with Clip t...
# ..                                                 ...
# 341  1/2 in x 36 yd, 72 individually wrapped rolls ...
# 342           1/2 in x 36 yd 5.2 mil, 72 per case Bulk
# 343  1 in x 36 yd, 36 individually wrapped rolls pe...
# 344                              10/pack, 6 packs/case
# 345                    8210 Performance Respirator N95
#
#                                           meta_keyword
# 0    Steel Dual Cam Rope Grab, Fall Protection 5/8"...
# 1              Feather Harness Fall Protection Harness
# 2    6' Dual Leg Lanyard w/ Shock Absorber 100% Tie...
# 3    Feather Positioning Harness with Back and Wais...
# 4    6' Shock Absorbing Lanyard with Clip to Tie Ba...
# ..                                                 ...
# 341                            Vinyl Tape 471 - Yellow
# 342                            Vinyl Tape 471 - Yellow
# 343                            Vinyl Tape 471 - Yellow
# 344                              10/pack, 6 packs/case
# 345                    8210 Performance Respirator N95
#
# [346 rows x 13 columns]>
# <ipython-input-71-6cb6aad58e16>:24: FutureWarning: The default value of regex will change from True to False in a future version.
#   df['Image'] = df['Image'].str.replace('/\\\\', 'E:\\\\IMAGES\\\\ITEMS\\\\product\\\\')
# ---------------------------------------------------------------------------
# PermissionError                           Traceback (most recent call last)
# <ipython-input-71-6cb6aad58e16> in <module>
#      33     #Change the folder path accordingly and make sure folder exists. This is where the file will save.
#      34     folder_path = "./Properly-Formatted-Files/" + 'v2' + file
# ---> 35     df.to_csv(folder_path, encoding='utf-8-sig', index=False)
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\core\generic.py in to_csv(self, path_or_buf, sep, na_rep, float_format, columns, header, index, index_label, mode, encoding, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, decimal, errors, storage_options)
#    3385         )
#    3386
# -> 3387         return DataFrameRenderer(formatter).to_csv(
#    3388             path_or_buf,
#    3389             line_terminator=line_terminator,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\formats\format.py in to_csv(self, path_or_buf, encoding, sep, columns, index_label, mode, compression, quoting, quotechar, line_terminator, chunksize, date_format, doublequote, escapechar, errors, storage_options)
#    1081             formatter=self.fmt,
#    1082         )
# -> 1083         csv_formatter.save()
#    1084
#    1085         if created_buffer:
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\formats\csvs.py in save(self)
#     226         """
#     227         # apply compression and byte/text conversion
# --> 228         with get_handle(
#     229             self.filepath_or_buffer,
#     230             self.mode,
#
# ~\AppData\Roaming\Python\Python38\site-packages\pandas\io\common.py in get_handle(path_or_buf, mode, encoding, compression, memory_map, is_text, errors, storage_options)
#     640                 errors = "replace"
#     641             # Encoding
# --> 642             handle = open(
#     643                 handle,
#     644                 ioargs.mode,
#
# PermissionError: [Errno 13] Permission denied: './Properly-Formatted-Files/v23M-ManufacturerExport-2-1-2021.csv'

# %%
# Note - The only 13 needed columns are:
# category_ids, category_names, Vendor Item/SKU, meta_title, meta_description, Image, manufacturer
# description, short_description, summary, upc, size_info, meta_keyword
